# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# This notebook reads CSV United Nations population tables and produces an xarray Dataset to be read by the AgriFoodPy package when importing the population modules.
#
# ``` python
# from agrifoodpy.population.population import UN
# ```
#
# The dimension coordinates of the array are
# - **Year**
# - **Region code**
# - Region name
# - **Datatype**
#
# In bold, the coordinates used to index the array. The *Region name* coordinate is for easy labelling and identification of regions.
#
# The original CSV file read in this notebook can be obtained here: https://population.un.org/wpp/Download/Standard/CSV/
#
# after accessing the **Total Population** Sub Group file:
# https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/CSV_FILES/WPP2022_TotalPopulationBySex.csv
#
# Population estimates are separated into 9 different *variants* for different combinations of fertility, mortality and international migration, which has different effects on different regions but cancels out at the *world* level.
#
# - Medium
# - High
# - Low
# - Constant fertility
# - Instant replacement
# - Zero migration
# - Constant mortality
# - No change
# - Momentum
# - Instant replacement zero migration
#
# Additionally, uncertainty values are given for the Medium projection
#
# - Median PI
# - Upper 80 PI
# - Lower 80 PI
# - Upper 95 PI
# - Lower 95 PI

# %%
# Last published year 
year = 2022

# %%
pop = pd.read_csv(f'../data/population/WPP{year}_TotalPopulationBySex.csv')
pop.head()
# Out:
# /tmp/ipykernel_351506/2773614349.py:1: DtypeWarning: Columns (2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pop = pd.read_csv(f'../data/population/WPP{year}_TotalPopulationBySex.csv')
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0        NaN   1857   NaN       NaN       NaN        NaN        NaN
# 1        NaN   1857   NaN       NaN       NaN        NaN        NaN
# 2        NaN   1857   NaN       NaN       NaN        NaN        NaN
# 3        NaN   1857   NaN       NaN       NaN        NaN        NaN
# 4        NaN   1857   NaN       NaN       NaN        NaN        NaN
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod     PopMale  \
# 0         NaN       NaN    AUKUS      2  Medium  1950     1950.5  101683.967
# 1         NaN       NaN    AUKUS      2  Medium  1951     1951.5  103204.345
# 2         NaN       NaN    AUKUS      2  Medium  1952     1952.5  104727.488
# 3         NaN       NaN    AUKUS      2  Medium  1953     1953.5  106093.466
# 4         NaN       NaN    AUKUS      2  Medium  1954     1954.5  107669.185
#
#     PopFemale    PopTotal  PopDensity
# 0  104829.814  206513.782      12.096
# 1  106085.841  209290.187      12.259
# 2  107331.845  212059.333      12.421
# 3  108905.518  214998.984      12.593
# 4  110509.997  218179.182      12.779

# %% [markdown]
# ## Region and subregions
#
# Data for regions and geographic regions is provided in the dataset. Using the "ParentID" column we can track back to the each parent region.
#
# For some reason, Canada, USA, Greenland, Saint Pierre and Miquelon, and Bermuda in Northern America are not assined to their respective region when tracking the ParentID column
# We assign these manually.

# %%
loc_ID = pop["LocID"].unique()
loc_name = []
loc_type = []
loc_subr = []
loc_regn = []

def find_loc_name(ID):
    lname = pop[pop["LocID"]==ID]["Location"].iloc[0]
    ltype = pop[pop["LocID"]==ID]["LocTypeName"].iloc[0]
    p_id = pop[pop["LocID"]==ID]["ParentID"].iloc[0]
    
    return lname, ltype, p_id

for id in loc_ID:
    lname, ltype, p_id = find_loc_name(id)
    loc_name.append(lname)
    loc_type.append(ltype)
    
    if np.isnan(p_id):
        loc_subr.append(np.nan)
        loc_regn.append(np.nan)
        continue
    
    try:
        p_name, _, p_p_id,=  find_loc_name(p_id)
    except IndexError:
        loc_subr.append(np.nan)
        loc_regn.append(np.nan)
        continue
        
    loc_subr.append(p_name)
    try:
        p_p_name = find_loc_name(p_p_id)[0]
    except IndexError:
        loc_regn.append(np.nan)
        continue
    loc_regn.append(p_p_name)

# %%
mask = np.where(np.isin(loc_ID, [124, 60, 840, 304, 666]))[0]
for index in mask:
    loc_regn[index] = "Northern America"
    loc_subr[index] = "Northern America"

# %%
for ir in range(len(loc_ID)):
    print(loc_ID[ir], loc_name[ir], loc_type[ir], loc_subr[ir], loc_regn[ir])
# Out:
# 1857 AUKUS nan nan nan
# 1823 African Group nan nan nan
# 1560 African Union nan nan nan
# 2080 African Union: Central Africa nan nan nan
# 2081 African Union: Eastern Africa nan nan nan
# 2082 African Union: Northern Africa nan nan nan
# 2083 African Union: Southern Africa nan nan nan
# 2084 African Union: Western Africa nan nan nan
# 1200 African, Caribbean and Pacific (ACP) Group of States nan nan nan
# 1533 Andean Community nan nan nan
# 1207 Asia-Pacific Economic Cooperation (APEC) nan nan nan
# 1824 Asia-Pacific Group nan nan nan
# 1557 Association of Southeast Asian Nations (ASEAN) nan nan nan
# 1525 BRIC nan nan nan
# 1526 BRICS nan nan nan
# 2067 Belt-Road Initiative (BRI) nan nan nan
# 2068 Belt-Road Initiative: Africa nan nan nan
# 2069 Belt-Road Initiative: Asia nan nan nan
# 2070 Belt-Road Initiative: Europe nan nan nan
# 2071 Belt-Road Initiative: Latin America and the Caribbean nan nan nan
# 2072 Belt-Road Initiative: Pacific nan nan nan
# 1527 Black Sea Economic Cooperation (BSEC) nan nan nan
# 1569 Bolivarian Alliance for the Americas (ALBA) nan nan nan
# 1858 CANZUK nan nan nan
# 1530 Caribbean Community and Common Market (CARICOM) nan nan nan
# 1545 Central European Free Trade Agreement (CEFTA) nan nan nan
# 1105 China (and dependencies) nan nan nan
# 1566 Commonwealth of Independent States (CIS) nan nan nan
# 2074 Commonwealth of Nations nan nan nan
# 2075 Commonwealth: Africa nan nan nan
# 2076 Commonwealth: Asia nan nan nan
# 2077 Commonwealth: Caribbean and Americas nan nan nan
# 2078 Commonwealth: Europe nan nan nan
# 2079 Commonwealth: Pacific nan nan nan
# 1638 Countries with Access to the Sea nan nan nan
# 2094 Countries with Access to the Sea: Africa nan nan nan
# 2095 Countries with Access to the Sea: Asia nan nan nan
# 2096 Countries with Access to the Sea: Europe nan nan nan
# 2097 Countries with Access to the Sea: Latin America and the Caribbean nan nan nan
# 2098 Countries with Access to the Sea: Northern America nan nan nan
# 2099 Countries with Access to the Sea: Oceania nan nan nan
# 1106 Denmark (and dependencies) nan nan nan
# 780 Trinidad and Tobago Country/Area Caribbean Latin America and the Caribbean
# 796 Turks and Caicos Islands Country/Area Caribbean Latin America and the Caribbean
# 850 United States Virgin Islands Country/Area Caribbean Latin America and the Caribbean
# 916 Central America Subregion Latin America and the Caribbean nan
# 84 Belize Country/Area Central America Latin America and the Caribbean
# 188 Costa Rica Country/Area Central America Latin America and the Caribbean
# 222 El Salvador Country/Area Central America Latin America and the Caribbean
# 320 Guatemala Country/Area Central America Latin America and the Caribbean
# 340 Honduras Country/Area Central America Latin America and the Caribbean
# 484 Mexico Country/Area Central America Latin America and the Caribbean
# 558 Nicaragua Country/Area Central America Latin America and the Caribbean
# 591 Panama Country/Area Central America Latin America and the Caribbean
# 931 South America Subregion Latin America and the Caribbean nan
# 32 Argentina Country/Area South America Latin America and the Caribbean
# 68 Bolivia (Plurinational State of) Country/Area South America Latin America and the Caribbean
# 76 Brazil Country/Area South America Latin America and the Caribbean
# 152 Chile Country/Area South America Latin America and the Caribbean
# 170 Colombia Country/Area South America Latin America and the Caribbean
# 218 Ecuador Country/Area South America Latin America and the Caribbean
# 238 Falkland Islands (Malvinas) Country/Area South America Latin America and the Caribbean
# 254 French Guiana Country/Area South America Latin America and the Caribbean
# 328 Guyana Country/Area South America Latin America and the Caribbean
# 600 Paraguay Country/Area South America Latin America and the Caribbean
# 604 Peru Country/Area South America Latin America and the Caribbean
# 740 Suriname Country/Area South America Latin America and the Caribbean
# 858 Uruguay Country/Area South America Latin America and the Caribbean
# 862 Venezuela (Bolivarian Republic of) Country/Area South America Latin America and the Caribbean
# 905 Northern America Geographic region nan nan
# 60 Bermuda Country/Area Northern America Northern America
# 124 Canada Country/Area Northern America Northern America
# 304 Greenland Country/Area Northern America Northern America
# 666 Saint Pierre and Miquelon Country/Area Northern America Northern America
# 840 United States of America Country/Area Northern America Northern America
# 909 Oceania Geographic region nan nan
# 927 Australia/New Zealand Subregion Oceania nan
# 36 Australia Country/Area Australia/New Zealand Oceania
# 554 New Zealand Country/Area Australia/New Zealand Oceania
# 928 Melanesia Subregion Oceania nan
# 242 Fiji Country/Area Melanesia Oceania
# 540 New Caledonia Country/Area Melanesia Oceania
# 598 Papua New Guinea Country/Area Melanesia Oceania
# 90 Solomon Islands Country/Area Melanesia Oceania
# 548 Vanuatu Country/Area Melanesia Oceania
# 954 Micronesia Subregion Oceania nan
# 316 Guam Country/Area Micronesia Oceania
# 296 Kiribati Country/Area Micronesia Oceania
# 584 Marshall Islands Country/Area Micronesia Oceania
# 583 Micronesia (Fed. States of) Country/Area Micronesia Oceania
# 520 Nauru Country/Area Micronesia Oceania
# 580 Northern Mariana Islands Country/Area Micronesia Oceania
# 585 Palau Country/Area Micronesia Oceania
# 957 Polynesia Subregion Oceania nan
# 16 American Samoa Country/Area Polynesia Oceania
# 184 Cook Islands Country/Area Polynesia Oceania
# 258 French Polynesia Country/Area Polynesia Oceania
# 570 Niue Country/Area Polynesia Oceania
# 882 Samoa Country/Area Polynesia Oceania
# 772 Tokelau Country/Area Polynesia Oceania
# 776 Tonga Country/Area Polynesia Oceania
# 798 Tuvalu Country/Area Polynesia Oceania
# 876 Wallis and Futuna Islands Country/Area Polynesia Oceania

# %%
years = pd.unique(pop["Time"])
variants = pd.unique(pop["Variant"])
datatypes = ["Total", "Male", "Female", "Density"] 

# Some numpy trickery to get the indices for the area, elements and items
iy = np.nonzero(pop['Time'].to_numpy()[:, None] == years)[1]
il = np.nonzero(pop['LocID'].to_numpy()[:, None] == loc_ID)[1]
iv = np.nonzero(pop['Variant'].to_numpy()[:, None] == variants)[1]

# We compute the index in the flattened array
ipos = iy * len(loc_ID) * len(variants) + il * len(variants) + iv
        
ipos = ipos.astype(int)

# %%
pop_total = np.ones(len(years)*len(loc_ID)*len(variants))*np.NaN
pop_male = np.ones(len(years)*len(loc_ID)*len(variants))*np.NaN
pop_female = np.ones(len(years)*len(loc_ID)*len(variants))*np.NaN
pop_dens = np.ones(len(years)*len(loc_ID)*len(variants))*np.NaN

pop_total[ipos] = pop['PopTotal']
pop_male[ipos] = pop['PopMale']
pop_female[ipos] = pop['PopFemale']
pop_dens[ipos] = pop['PopDensity']

pop_total = pop_total.reshape(len(years), len(loc_ID), len(variants))
pop_female = pop_female.reshape(len(years), len(loc_ID), len(variants))
pop_male = pop_male.reshape(len(years), len(loc_ID), len(variants))
pop_dens = pop_dens.reshape(len(years), len(loc_ID), len(variants))

pop_arr = np.ones((len(years), len(loc_ID), len(variants), len(datatypes)))

for idt, data_arr in enumerate([pop_total, pop_male, pop_female, pop_dens]):
    pop_arr[...,idt] = data_arr

# %%
pop[pop["Location"]=="United States of America"]
# Out:
#         SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 514413      262.0    840  31.0       USA        US      840.0        4.0
# 514414      262.0    840  31.0       USA        US      840.0        4.0
# 514415      262.0    840  31.0       USA        US      840.0        4.0
# 514416      262.0    840  31.0       USA        US      840.0        4.0
# 514417      262.0    840  31.0       USA        US      840.0        4.0
# ...           ...    ...   ...       ...       ...        ...        ...
# 515665      262.0    840  31.0       USA        US      840.0        4.0
# 515666      262.0    840  31.0       USA        US      840.0        4.0
# 515667      262.0    840  31.0       USA        US      840.0        4.0
# 515668      262.0    840  31.0       USA        US      840.0        4.0
# 515669      262.0    840  31.0       USA        US      840.0        4.0
#
#          LocTypeName  ParentID                  Location  VarID      Variant  \
# 514413  Country/Area     918.0  United States of America      2       Medium
# 514414  Country/Area     918.0  United States of America      2       Medium
# 514415  Country/Area     918.0  United States of America      2       Medium
# 514416  Country/Area     918.0  United States of America      2       Medium
# 514417  Country/Area     918.0  United States of America      2       Medium
# ...              ...       ...                       ...    ...          ...
# 515665  Country/Area     918.0  United States of America    207  Lower 95 PI
# 515666  Country/Area     918.0  United States of America    207  Lower 95 PI
# 515667  Country/Area     918.0  United States of America    207  Lower 95 PI
# 515668  Country/Area     918.0  United States of America    207  Lower 95 PI
# 515669  Country/Area     918.0  United States of America    207  Lower 95 PI
#
#         Time  MidPeriod     PopMale   PopFemale    PopTotal  PopDensity
# 514413  1950     1950.5   73516.095   74765.455  148281.550      16.210
# 514414  1951     1951.5   74784.499   75813.955  150598.453      16.463
# 514415  1952     1952.5   76079.283   76862.444  152941.727      16.719
# 514416  1953     1953.5   77221.443   78229.756  155451.199      16.994
# 514417  1954     1954.5   78577.893   79627.980  158205.873      17.295
# ...      ...        ...         ...         ...         ...         ...
# 515665  2096     2096.5  147409.224  150282.115  299545.109      32.746
# 515666  2097     2097.5  146497.408  149522.313  297876.458      32.563
# 515667  2098     2098.5  145646.516  148670.814  295844.406      32.341
# 515668  2099     2099.5  145047.307  147555.848  293706.699      32.108
# 515669  2100     2100.5  144373.338  146493.541  291820.279      31.901
#
# [1257 rows x 18 columns]

# %%
data = xr.Dataset(
    coords = dict(
        Year=("Year", years),
        Region=("Region", loc_ID),
        Region_name=("Region", loc_name),
        Region_type=("Region", loc_type),
        Region_subregion=("Region", loc_subr),
        Region_region=("Region", loc_regn),
        Datatype=("Datatype", datatypes)
    )
)

for iv, variant in enumerate(variants):
    data = data.assign({variant:(["Year", "Region", "Datatype"], pop_arr[:,:,iv,:])})

# %%
# Checking the coordinates of North American regions

# Canada: 124
# Bermuda: 60
# United States of America: 840
# Greenland: 304
# Saint Pierre and Miquelon: 666

data.sel(Region=[124, 60, 840, 304, 666])
# Out:
# <xarray.Dataset>
# Dimensions:                             (Year: 151, Region: 5, Datatype: 4)
# Coordinates:
#   * Year                                (Year) int64 1950 1951 ... 2099 2100
#   * Region                              (Region) int64 124 60 840 304 666
#     Region_name                         (Region) <U93 'Canada' ... 'Saint Pie...
#     Region_type                         (Region) <U32 'Country/Area' ... 'Cou...
#     Region_subregion                    (Region) <U32 'Northern America' ... ...
#     Region_region                       (Region) <U32 'Northern America' ... ...
#   * Datatype                            (Datatype) <U7 'Total' ... 'Density'
# Data variables: (12/15)
#     Medium                              (Year, Region, Datatype) float64 1.37...
#     High                                (Year, Region, Datatype) float64 nan ...
#     Low                                 (Year, Region, Datatype) float64 nan ...
#     Constant fertility                  (Year, Region, Datatype) float64 nan ...
#     Instant replacement                 (Year, Region, Datatype) float64 nan ...
#     Zero migration                      (Year, Region, Datatype) float64 nan ...
#     ...                                  ...
#     Instant replacement zero migration  (Year, Region, Datatype) float64 nan ...
#     Median PI                           (Year, Region, Datatype) float64 nan ...
#     Upper 80 PI                         (Year, Region, Datatype) float64 nan ...
#     Lower 80 PI                         (Year, Region, Datatype) float64 nan ...
#     Upper 95 PI                         (Year, Region, Datatype) float64 nan ...
#     Lower 95 PI                         (Year, Region, Datatype) float64 nan ...

# %%
plt.plot(data.Year.values, data.Medium.sel(Region=data.Region_name=="United Kingdom", Datatype="Male"))

# %%
encoding = {}

for variant in variants:
    encoding[variant] = {"dtype":"float32", "zlib": True, "complevel": 5}

data.to_netcdf("data/UN.nc", encoding = encoding)
